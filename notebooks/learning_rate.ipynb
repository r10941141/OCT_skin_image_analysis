# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0715_noise_lr0.0001_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-15 16:04:39.687756: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-15 16:04:39.777114: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0715_noise_lr0.00004_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-15 15:25:32.537494: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-15 15:25:32.686377: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0715_noise_lr0.001_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-16 12:42:19.578728: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-16 12:42:19.652085: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0715_noise_lr0.0001_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-16 16:36:36.729725: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-16 16:36:36.799708: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0628_10_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0628_10_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-16 22:37:04.787733: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-16 22:37:04.856218: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 510.07it/s]
# time read 12.479004144668579 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0628_100_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0628_100_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-16 22:45:26.027422: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-16 22:45:26.096024: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 510.14it/s]
# time read 12.50039005279541 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_oct_nopretrain_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_oct_nopretrain_8_And/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_oct/test/
# Out:
# 2023-07-16 22:53:47.776598: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-16 22:53:47.846148: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 510.30it/s]
# time read 12.543336153030396 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_oct_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_oct_8_And/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_oct/test/
# Out:
# 2023-07-16 23:02:11.683251: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-16 23:02:11.752146: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 507.91it/s]
# time read 12.53192138671875 s
# Done!
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0715_noise_lr0.004_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-18 16:04:58.187323: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-18 16:04:58.262815: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0715_noise_lr0.004_8_Andy/ \
--save_mask_path /Workspace/pred_mask_testing_data_0715_noise_lr0.004_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-19 09:00:44.424313: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 09:00:44.550562: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 510.92it/s]
# time read 12.476080656051636 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0715_noise_lr0.00004_8_Andy/ \
--save_mask_path /Workspace/pred_mask_testing_data_0715_noise_lr0.00004_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-20 19:30:03.654416: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-20 19:30:03.722685: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 504.92it/s]
# time read 12.584092855453491 s
# Done!
# ...
