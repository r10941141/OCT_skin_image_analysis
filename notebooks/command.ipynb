# %%
# !nvidia-smi

# %%
# !pip install tqdm
# !pip install scikit-image
# !pip install scikit-learn
# !pip install argparse

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 16\
--savefile_path /Workspace/datafile_batchsize_0616 \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy
# Out:
# 2023-07-20 10:13:14.858488: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-20 10:13:14.944620: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0705_skew_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-06 10:33:33.914888: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 10:33:33.982661: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0705_noise_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-06 15:07:59.732892: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 15:07:59.800294: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0705_prenoise_skew \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_0705_noise_8_Andy/ML_for_skin.hdf5
# Out:
# 2023-07-06 19:02:56.290046: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 19:02:56.356858: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0705_10_skew \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-06 23:21:11.460109: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 23:21:11.528259: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0705_noise_preskew_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_0705_noise_8_Andy/ML_for_skin.hdf5
# Out:
# 2023-07-08 00:01:14.792408: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-08 00:01:14.866868: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0709_noise_preskew_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_0705_10_skew8_Andy/ML_for_skin.hdf5
# Out:
# 2023-07-08 16:33:03.230378: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-08 16:33:03.301893: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0710_noise_preskew_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_0705_10_skew8_Andy/ML_for_skin.hdf5
# Out:
# 2023-07-09 19:39:13.591811: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-09 19:39:13.659050: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 4\
--savefile_path /Workspace/datafile_batchsize_0616 \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy
# Out:
# 2023-06-19 15:51:26.150119: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-19 15:51:26.220922: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:46: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 1\
--savefile_path /Workspace/datafile_batchsize_0616 \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy
# Out:
# 2023-06-23 19:43:42.471293: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-23 19:43:42.543354: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:46: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 mask_output.py
# Out:
# 2023-06-15 16:20:26.305998: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-15 16:20:26.377169: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 509.83it/s]
# time read 12.449058055877686 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_06161Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_06161/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-06-29 08:15:44.963009: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 08:15:45.032563: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 511.03it/s]
# time read 12.470434188842773 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_06162Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_06162/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-06-29 08:36:28.965542: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 08:36:29.033669: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 511.19it/s]
# time read 12.478550672531128 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_06164Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_06164/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-06-29 08:57:17.636958: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 08:57:17.706177: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 512.59it/s]
# time read 12.466342210769653 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_061616Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_061616/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-06-30 15:44:41.661407: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-30 15:44:41.730002: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 507.52it/s]
# time read 12.623658657073975 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_noise_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_noise_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-07 15:53:24.363935: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-07 15:53:24.431267: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 509.04it/s]
# time read 12.511456489562988 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_noise_preskew_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_noise_preskew_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-08 15:47:47.913186: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-08 15:47:47.981120: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 508.23it/s]
# time read 12.537500143051147 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_10_skew8_Andy/\
--save_mask_path /Workspace/datafile_batchsize_0705_10_skew8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-09 03:57:20.217130: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-09 03:57:20.285950: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# ...
#  51%|███████████████████▌                  | 1609/3125 [00:03<00:03, 498.27it/s]
# Traceback (most recent call last):
#   File "mask_output.py", line 61, in <module>
#     img = imread(path)[:,:]
#   File "/usr/local/lib/python3.8/dist-packages/skimage/io/_io.py", line 53, in imread
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_prenoise_skew8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_prenoise_skew8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-09 04:21:18.097777: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-09 04:21:18.171365: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 479.24it/s]
# time read 13.189629077911377 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_10_skew8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_10_skew8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-09 04:30:08.879186: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-09 04:30:08.951952: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 482.81it/s]
# time read 13.146783113479614 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0709_noise_preskew_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0709_noise_preskew_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-09 14:44:39.429248: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-09 14:44:39.499869: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 484.31it/s]
# time read 13.074107646942139 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0710_noise_preskew_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0710_noise_preskew_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-10 05:13:10.191240: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-10 05:13:10.258925: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 506.60it/s]
# time read 12.555930852890015 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0710_noise_preskew_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0710_noise_preskew_8_0.4_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-10 12:19:40.979699: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-10 12:19:41.047318: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 505.01it/s]
# time read 12.56766390800476 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0710_noise_preskew_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0710_noise_preskew_8_0.4_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-10 12:28:05.013216: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-10 12:28:05.080366: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 506.28it/s]
# time read 12.540996074676514 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_oct_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_oct_8_And/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_oct/test/
# Out:
# 2023-07-14 13:37:18.738902: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-14 13:37:18.809982: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 506.04it/s]
# time read 12.578994035720825 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0705_oct_nopretrain_8_Andy/\
--save_mask_path /Workspace/pred_mask_testing_data_0705_oct_nopretrain_8_And/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_oct/test/
# Out:
# 2023-07-14 13:45:42.851858: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-14 13:45:42.919683: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 513.29it/s]
# time read 12.413576126098633 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0715_noise_lr0.00001_8_Andy/ \
--save_mask_path /Workspace/pred_mask_testing_data_0715_noise_lr0.00001_8_Andy/ \
--splits_n 4 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-17 09:38:39.548497: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-17 09:38:39.617189: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 478.32it/s]
# time read 13.249426126480103 s
# Done!
# ...

# %%
# !python3 mask_output.py --model_path /Workspace/datafile_batchsize_0715_noise_lr0.001_8_Andy/ \
--save_mask_path /Workspace/pred_mask_testing_data_0715_noise_lr0.001_8_Andy/ \
--splits_n 5 \
--TEST_PATH /Workspace/images_andy/test/
# Out:
# 2023-07-18 10:08:46.627325: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-18 10:08:46.697463: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Resizing test images
# 100%|██████████████████████████████████████| 3125/3125 [00:06<00:00, 473.67it/s]
# time read 13.366396188735962 s
# Done!
# ...

# %%
# !python3 demo4.py --epoch1 10 --splits_n 2 --batch_size 16\
--savefile_path /Workspace/datafile_batchsize \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy
# Out:
# 2023-06-01 10:31:39.595168: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-01 10:31:39.667333: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:46: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 10 --splits_n 2 --batch_size 1\
--savefile_path /Workspace/datafile_batchsize \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy
# Out:
# 2023-06-01 10:35:37.487734: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-01 10:35:37.558700: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:46: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 10 --splits_n 5 --batch_size 16\
--savefile_path /Workspace/datafile_batchsize \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy
# Out:
# 2023-06-01 12:36:20.533787: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-01 12:36:20.604513: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:46: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0628_100_ \
--TRAIN_PATH /Workspace/images_andy/train/ \
--TEST_PATH /Workspace/images_andy/test/ \
--data_from Andy
# Out:
# 2023-07-02 16:12:56.475752: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-02 16:12:56.545338: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:47: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0705_oct_ \
--TRAIN_PATH /Workspace/images_oct/train/ \
--TEST_PATH /Workspace/images_oct/test/ \
--data_from Andy \
--pretrain_model_path /Workspace/datafile_batchsize_06168Andy/ML_for_skin.hdf5
# Out:
# 2023-07-12 06:08:42.765875: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-12 06:08:42.834674: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...

# %%
# !python3 demo4.py --epoch1 100 --splits_n 5 --batch_size 8\
--savefile_path /Workspace/datafile_batchsize_0705_oct_nopretrain_ \
--TRAIN_PATH /Workspace/images_oct/train/ \
--TEST_PATH /Workspace/images_oct/test/ \
--data_from Andy
# Out:
# 2023-07-12 15:36:29.609848: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-12 15:36:29.677383: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# demo4.py:49: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# ...
